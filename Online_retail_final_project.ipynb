# %% [markdown]
# **Objectives of the project**
# *   Total revenue generated
# *   Total orders placed
# *   Total products sold
# *   Average order value
# *   Top 10 products sold
# *   Quarterly sales bar chart
# *   Top products by revenue
# *   Least-performing products
# *   Number of unique customers
# *   Average spending
# *   Customer order frequency

# %% [markdown]
# Dataset Overview
#
# The dataset used in this project is sourced from kaggle.The URL is
# https://www.kaggle.com/datasets/vijayuv/onlineretail?utm_source=chatgpt.com

# %% [markdown]
# Column Description
#
# InvoiceNo,StockCode,Description,Quantity,InvoiceDate,UnitPrice,CustomerID,Country

# %% [markdown]
# Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5ebb2b23-8d97-4da4-967a-e4d050eeb2e3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5ebb2b23-8d97-4da4-967a-e4d050eeb2e3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
dh=pd.read_csv("OnlineRetail.csv.zip", encoding='latin1')
dh
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
print(dh.head())
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
print(dh.tail())
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID Country
# 541904  12/9/2011 12:50       0.85     12680.0  France
# 541905  12/9/2011 12:50       2.10     12680.0  France
# 541906  12/9/2011 12:50       4.15     12680.0  France
# 541907  12/9/2011 12:50       4.15     12680.0  France
# 541908  12/9/2011 12:50       4.95     12680.0  France

# %%
print(dh.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB
# None

# %%
print(dh.describe)
# Out:
# <bound method NDFrame.describe of        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
# ...

# %%
print(dh.sample())
# Out:
#        InvoiceNo StockCode               Description  Quantity  \
# 144951    548861     22423  REGENCY CAKESTAND 3 TIER         3
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 144951  4/4/2011 13:42      12.75     18185.0  United Kingdom

# %%
print(dh.dtypes)
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %%
print("Rows",dh.shape[0])
print("Columns",dh.shape[1])
# Out:
# Rows 541909
# Columns 8

# %% [markdown]
# Total price

# %%
print(dh.isnull().sum())
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %% [markdown]
# Total Revenue Generated

# %%
dh['total_price']=dh['UnitPrice']*dh['Quantity']
print('total_price')
print(dh.head())
# Out:
# total_price
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country  total_price
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom        15.30
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom        20.34
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom        22.00
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom        20.34
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom        20.34

# %%
total_revenue=dh['total_price'].sum()
print("Total Revenue:",total_revenue)
# Out:
# Total Revenue: 9747747.933999998

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=monthly_revenue.index, y=monthly_revenue.values)
plt.title('Total Revenue Over Time')
plt.xlabel('Month')
plt.ylabel('Total Revenue')
plt.show()

# %% [markdown]
# Total orders placed

# %%
orders=dh['InvoiceNo'].nunique()
print("Total Orders Placed is",orders)
# Out:
# Total Orders Placed is 25900

# %% [markdown]
# Total products sold

# %%
total_products=dh['StockCode'].nunique()
print("Total products :",total_products)
# Out:
# Total products : 4070

# %% [markdown]
# Average order value

# %%
average_order_value = total_revenue / orders
print("Average Order Value:", average_order_value)
# Out:
# Average Order Value: 376.36092409266405

# %% [markdown]
# Monthly sales

# %%
dh['Invoice_Date']=pd.to_datetime(dh['InvoiceDate'])
dh['Month']=dh['Invoice_Date'].dt.month
monthly_revenue=dh.groupby('Month')['total_price'].sum()
print(monthly_revenue)
# Out:
# Month
# 1      560000.260
# 2      498062.650
# 3      683267.080
# 4      493207.121
# 5      723333.510
# 6      691123.120
# 7      681300.111
# 8      682680.510
# 9     1019687.622
# 10    1070704.670
# 11    1461756.250
# 12    1182625.030
# Name: total_price, dtype: float64

# %% [markdown]
# Monthly sales line chart

# %%
sns.relplot(x='Month',y='total_price',data=dh,kind='line',height=6,aspect=2)
plt.title('Monthly Revenue')
plt.show()

# %% [markdown]
# Top 10 products sold

# %%
top_10_products=dh.groupby('Description')['Quantity'].sum().sort_values(ascending=False).head(10)
print(top_10_products)

# %% [markdown]
# Monthly sales line chart

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load dh DataFrame if not already defined (or ensure it's loaded)
dh = pd.read_csv("/content/OnlineRetail.csv.zip", encoding='latin1')

# Recalculate top_10_products to ensure it's defined
top_10_products=dh.groupby('Description')['Quantity'].sum().sort_values(ascending=False).head(10)
sns.barplot(x=top_10_products.index,y=top_10_products.values)
plt.title('Top 10 Products')
plt.show()

# %% [markdown]
# Quarterly sales bar chart

# %%
dh['Quarter']=dh['Invoice_Date'].dt.quarter

# %%
quarter_revenue=dh.groupby('Quarter')['total_price'].sum()
print(quarter_revenue)
# Out:
# Quarter
# 1    1741329.990
# 2    1907663.751
# 3    2383668.243
# 4    3715085.950
# Name: total_price, dtype: float64

# %%
sns.barplot(x=quarter_revenue.index,y=quarter_revenue.values)
plt.title('Quarterly Revenue')
plt.show()

# %% [markdown]
# Top products by revenue

# %%
top_product_revenue=dh.groupby('Description')['total_price'].sum().sort_values(ascending=False).head(10)
print(top_product_revenue)
# Out:
# Description
# DOTCOM POSTAGE                        206245.48
# REGENCY CAKESTAND 3 TIER              164762.19
# WHITE HANGING HEART T-LIGHT HOLDER     99668.47
# PARTY BUNTING                          98302.98
# JUMBO BAG RED RETROSPOT                92356.03
# RABBIT NIGHT LIGHT                     66756.59
# POSTAGE                                66230.64
# PAPER CHAIN KIT 50'S CHRISTMAS         63791.94
# ASSORTED COLOUR BIRD ORNAMENT          58959.73
# CHILLI LIGHTS                          53768.06
# Name: total_price, dtype: float64

# %% [markdown]
# Least-performing products

# %%
least_performing=dh.groupby('Description')['total_price'].sum().sort_values(ascending=True).head(10)
print(least_performing)
# Out:
# Description
# AMAZON FEE                       -221520.500
# Manual                            -68671.640
# Adjust bad debt                   -11062.060
# CRUK Commission                    -7933.430
# Bank Charges                       -7175.639
# Discount                           -5696.220
# SAMPLES                            -3049.390
# WHITE CHERRY LIGHTS                  -54.000
# CREAM SWEETHEART MAGAZINE RACK       -46.850
# WOODEN BOX ADVENT CALENDAR           -45.700
# Name: total_price, dtype: float64

# %% [markdown]
# Number of unique customers

# %%
unique_customers=dh['CustomerID'].nunique()
print("Unique Customers:",unique_customers)
print(dh.count())
# Out:
# Unique Customers: 4372
# InvoiceNo       541909
# StockCode       541909
# Description     540455
# Quantity        541909
# InvoiceDate     541909
# UnitPrice       541909
# CustomerID      406829
# Country         541909
# total_price     541909
# Invoice_Date    541909
# Month           541909
# Quarter         541909
# dtype: int64

# %% [markdown]
# Average spending per customer

# %%
average_spending=total_revenue/unique_customers
print("Average Spending Per Customer:",average_spending)
# Out:
# Average Spending Per Customer: 2229.5855292772185

# %% [markdown]
# Customer order frequency

# %%
customer_frequency=dh.groupby('CustomerID')['InvoiceNo'].nunique()
print(customer_frequency)
# Out:
# CustomerID
# 12346.0     2
# 12347.0     7
# 12348.0     4
# 12349.0     1
# 12350.0     1
#            ..
# 18280.0     1
# 18281.0     1
# 18282.0     3
# 18283.0    16
# 18287.0     3
# Name: InvoiceNo, Length: 4372, dtype: int64

# %%
avg_frequency=customer_frequency.mean()
print("Average Frequency:",avg_frequency)
# Out:
# Average Frequency: 5.07548032936871

# %%
customer_freq = (dh.groupby('CustomerID')['InvoiceNo'].nunique().reset_index(name='Frequency'))
print(customer_freq)
# Out:
#       CustomerID  Frequency
# 0        12346.0          2
# 1        12347.0          7
# 2        12348.0          4
# 3        12349.0          1
# 4        12350.0          1
# ...          ...        ...
# 4367     18280.0          1
# 4368     18281.0          1
# 4369     18282.0          3
# 4370     18283.0         16
# 4371     18287.0          3
#
# [4372 rows x 2 columns]

# %% [markdown]
# Revenue by country

# %%
revenue_country=dh.groupby('Country')['total_price'].sum().sort_values(ascending=False)
print(revenue_country)
# Out:
# Country
# United Kingdom          8187806.364
# Netherlands              284661.540
# EIRE                     263276.820
# Germany                  221698.210
# France                   197403.900
# Australia                137077.270
# Switzerland               56385.350
# Spain                     54774.580
# Belgium                   40910.960
# Sweden                    36595.910
# Japan                     35340.620
# Norway                    35163.460
# Portugal                  29367.020
# Finland                   22326.740
# Channel Islands           20086.290
# Denmark                   18768.140
# Italy                     16890.510
# Cyprus                    12946.290
# Austria                   10154.320
# Hong Kong                 10117.040
# Singapore                  9120.390
# Israel                     7907.820
# Poland                     7213.140
# Unspecified                4749.790
# Greece                     4710.520
# Iceland                    4310.000
# ...

# %%
top10 = revenue_country.sort_values(ascending=False).head(10)

plt.figure(figsize=(10,6))
sns.barplot(x=top10.values, y=top10.index)
plt.title('Top 10 Countries by Revenue')
plt.xlabel('Revenue')
plt.ylabel('Country')
plt.show()
